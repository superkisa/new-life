# %% [markdown]
# # Experimenting on ants

# %%
from pathlib import Path

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
from mujoco import viewer
from stable_baselines3 import SAC

# %% [markdown]
# ## Observing the observations

# %%
ant_xml = Path("assets/mujoco/models/ant-3.xml").resolve()
# env = gym.make('Ant-v4', ctrl_cost_weight=0.1, use_contact_forces=True, render_mode="human")
env = gym.make("Ant-v4", xml_file=str(ant_xml), render_mode="human")

# %%
observation, info = env.reset()

# %%
observation
# Out:
# array([ 0.66047925,  0.9971541 ,  0.06756732, -0.03341387, -0.00137028,
#        -0.07984521,  0.04375994, -0.0096046 ,  0.01226555, -0.08926691,
#        -0.02879555, -0.07376045,  0.04433621,  0.0964623 , -0.06174972,
#        -0.14143607,  0.08411178,  0.08991813, -0.07854903, -0.18739163,
#        -0.00394809, -0.05577037, -0.0477747 ])

# %%
s1, r1, terminated, truncated, inform = env.step([0]*6)

# %%
# plt.imshow(env.render()) # type: ignore

# %% [markdown]
# ## Saccing

# %%
# Loading the model
model = SAC.load("sac_ant_3legs")

# %%
model = SAC("MlpPolicy", env, verbose=1, tensorboard_log="./runs")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000)
# Out:
# Logging to ./runs\SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | -0.833   |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 53       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 621      |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.935    |
# |    ent_coef        | 0.856    |
# |    ent_coef_loss   | -1.56    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 520      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 254      |
# |    ep_rew_mean     | -14.1    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 52       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2029     |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 1.6      |
# |    ent_coef        | 0.563    |
# |    ent_coef_loss   | -5.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1928     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 321      |
# |    ep_rew_mean     | -27.9    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 52       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 3850     |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 2.39     |
# |    ent_coef        | 0.331    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3749     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 265      |
# |    ep_rew_mean     | -21      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 50       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 4237     |
# | train/             |          |
# |    actor_loss      | -32.5    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.296    |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4136     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 388      |
# |    ep_rew_mean     | -18.2    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 54       |
# |    time_elapsed    | 143      |
# |    total_timesteps | 7753     |
# | train/             |          |
# |    actor_loss      | -32      |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7652     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | 21.3     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 55       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 11008    |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 1.02     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 536      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 56       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 15008    |
# | train/             |          |
# |    actor_loss      | -30.5    |
# |    critic_loss     | 0.858    |
# |    ent_coef        | 0.0187   |
# |    ent_coef_loss   | -5.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 564      |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 56       |
# |    time_elapsed    | 317      |
# |    total_timesteps | 18043    |
# | train/             |          |
# |    actor_loss      | -33.5    |
# |    critic_loss     | 0.653    |
# |    ent_coef        | 0.0146   |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17942    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 612      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 57       |
# |    time_elapsed    | 385      |
# |    total_timesteps | 22043    |
# | train/             |          |
# |    actor_loss      | -39.3    |
# |    critic_loss     | 0.506    |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -0.375   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21942    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 651      |
# |    ep_rew_mean     | 307      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 57       |
# |    time_elapsed    | 452      |
# |    total_timesteps | 26043    |
# | train/             |          |
# |    actor_loss      | -44.3    |
# |    critic_loss     | 0.512    |
# |    ent_coef        | 0.0221   |
# |    ent_coef_loss   | -0.967   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25942    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 683      |
# |    ep_rew_mean     | 354      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 57       |
# |    time_elapsed    | 520      |
# |    total_timesteps | 30043    |
# | train/             |          |
# |    actor_loss      | -49.1    |
# |    critic_loss     | 0.516    |
# |    ent_coef        | 0.0227   |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29942    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 675      |
# |    ep_rew_mean     | 365      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 57       |
# |    time_elapsed    | 560      |
# |    total_timesteps | 32386    |
# | train/             |          |
# |    actor_loss      | -51.1    |
# |    critic_loss     | 0.395    |
# |    ent_coef        | 0.0227   |
# |    ent_coef_loss   | 0.369    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32285    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 700      |
# |    ep_rew_mean     | 403      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 57       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 36386    |
# | train/             |          |
# |    actor_loss      | -55.3    |
# |    critic_loss     | 0.586    |
# |    ent_coef        | 0.0235   |
# |    ent_coef_loss   | -0.428   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36285    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 429      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 58       |
# |    time_elapsed    | 695      |
# |    total_timesteps | 40386    |
# | train/             |          |
# |    actor_loss      | -57.8    |
# |    critic_loss     | 0.61     |
# |    ent_coef        | 0.023    |
# |    ent_coef_loss   | -0.0858  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40285    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 724      |
# |    ep_rew_mean     | 443      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 58       |
# |    time_elapsed    | 746      |
# |    total_timesteps | 43412    |
# | train/             |          |
# |    actor_loss      | -59.1    |
# |    critic_loss     | 0.547    |
# |    ent_coef        | 0.0233   |
# |    ent_coef_loss   | 0.616    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 725      |
# |    ep_rew_mean     | 456      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 58       |
# |    time_elapsed    | 797      |
# |    total_timesteps | 46424    |
# | train/             |          |
# |    actor_loss      | -60.7    |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.024    |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46323    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 742      |
# |    ep_rew_mean     | 481      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 58       |
# |    time_elapsed    | 865      |
# |    total_timesteps | 50424    |
# | train/             |          |
# |    actor_loss      | -62.5    |
# |    critic_loss     | 0.415    |
# |    ent_coef        | 0.0241   |
# |    ent_coef_loss   | 0.456    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50323    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 743      |
# |    ep_rew_mean     | 491      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 58       |
# |    time_elapsed    | 917      |
# |    total_timesteps | 53495    |
# | train/             |          |
# |    actor_loss      | -63.8    |
# |    critic_loss     | 0.385    |
# |    ent_coef        | 0.0232   |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53394    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 732      |
# |    ep_rew_mean     | 490      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 58       |
# |    time_elapsed    | 953      |
# |    total_timesteps | 55599    |
# | train/             |          |
# |    actor_loss      | -64.3    |
# |    critic_loss     | 0.408    |
# |    ent_coef        | 0.023    |
# |    ent_coef_loss   | -0.844   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 733      |
# |    ep_rew_mean     | 499      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 58       |
# |    time_elapsed    | 1004     |
# |    total_timesteps | 58641    |
# | train/             |          |
# |    actor_loss      | -65.4    |
# |    critic_loss     | 0.877    |
# |    ent_coef        | 0.0225   |
# |    ent_coef_loss   | 0.261    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58540    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 746      |
# |    ep_rew_mean     | 518      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 58       |
# |    time_elapsed    | 1069     |
# |    total_timesteps | 62641    |
# | train/             |          |
# |    actor_loss      | -67.2    |
# |    critic_loss     | 0.421    |
# |    ent_coef        | 0.0232   |
# |    ent_coef_loss   | 0.392    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62540    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 755      |
# |    ep_rew_mean     | 527      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 58       |
# |    time_elapsed    | 1131     |
# |    total_timesteps | 66435    |
# | train/             |          |
# |    actor_loss      | -68      |
# |    critic_loss     | 0.471    |
# |    ent_coef        | 0.022    |
# |    ent_coef_loss   | 0.847    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 766      |
# |    ep_rew_mean     | 544      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 58       |
# |    time_elapsed    | 1196     |
# |    total_timesteps | 70435    |
# | train/             |          |
# |    actor_loss      | -68.7    |
# |    critic_loss     | 0.327    |
# |    ent_coef        | 0.0218   |
# |    ent_coef_loss   | -0.323   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 775      |
# |    ep_rew_mean     | 560      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 59       |
# |    time_elapsed    | 1261     |
# |    total_timesteps | 74435    |
# | train/             |          |
# |    actor_loss      | -70.2    |
# |    critic_loss     | 0.22     |
# |    ent_coef        | 0.0215   |
# |    ent_coef_loss   | -0.431   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 784      |
# |    ep_rew_mean     | 573      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 59       |
# |    time_elapsed    | 1325     |
# |    total_timesteps | 78435    |
# | train/             |          |
# |    actor_loss      | -71.1    |
# |    critic_loss     | 0.329    |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 0.412    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 78334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 818      |
# |    ep_rew_mean     | 609      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 59       |
# |    time_elapsed    | 1390     |
# |    total_timesteps | 82435    |
# | train/             |          |
# |    actor_loss      | -72      |
# |    critic_loss     | 0.345    |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 0.945    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 844      |
# |    ep_rew_mean     | 642      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 59       |
# |    time_elapsed    | 1455     |
# |    total_timesteps | 86435    |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 0.363    |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 673      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 59       |
# |    time_elapsed    | 1504     |
# |    total_timesteps | 89463    |
# | train/             |          |
# |    actor_loss      | -72.9    |
# |    critic_loss     | 0.449    |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -0.867   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89362    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 883      |
# |    ep_rew_mean     | 697      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 59       |
# |    time_elapsed    | 1554     |
# |    total_timesteps | 92511    |
# | train/             |          |
# |    actor_loss      | -73.1    |
# |    critic_loss     | 0.381    |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | 0.751    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92410    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 888      |
# |    ep_rew_mean     | 734      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 59       |
# |    time_elapsed    | 1619     |
# |    total_timesteps | 96511    |
# | train/             |          |
# |    actor_loss      | -74.3    |
# |    critic_loss     | 0.189    |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | 0.864    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96410    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | 763      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 59       |
# |    time_elapsed    | 1684     |
# |    total_timesteps | 100511   |
# | train/             |          |
# |    actor_loss      | -74.6    |
# |    critic_loss     | 0.306    |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100410   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | 776      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 59       |
# |    time_elapsed    | 1749     |
# |    total_timesteps | 104511   |
# | train/             |          |
# |    actor_loss      | -75.2    |
# |    critic_loss     | 0.297    |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -1.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 104410   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 905      |
# |    ep_rew_mean     | 789      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 59       |
# |    time_elapsed    | 1814     |
# |    total_timesteps | 108511   |
# | train/             |          |
# |    actor_loss      | -75.8    |
# |    critic_loss     | 0.412    |
# |    ent_coef        | 0.0181   |
# |    ent_coef_loss   | 0.00655  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 108410   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | 782      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 59       |
# |    time_elapsed    | 1864     |
# |    total_timesteps | 111528   |
# | train/             |          |
# |    actor_loss      | -76.4    |
# |    critic_loss     | 0.159    |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | 784      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 59       |
# |    time_elapsed    | 1929     |
# |    total_timesteps | 115528   |
# | train/             |          |
# |    actor_loss      | -76.7    |
# |    critic_loss     | 0.454    |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | 1.43     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 115427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | 788      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 59       |
# |    time_elapsed    | 1994     |
# |    total_timesteps | 119528   |
# | train/             |          |
# |    actor_loss      | -77.2    |
# |    critic_loss     | 0.3      |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 806      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 59       |
# |    time_elapsed    | 2059     |
# |    total_timesteps | 123528   |
# | train/             |          |
# |    actor_loss      | -77.2    |
# |    critic_loss     | 0.451    |
# |    ent_coef        | 0.0187   |
# |    ent_coef_loss   | -0.501   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 123427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 808      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 60       |
# |    time_elapsed    | 2125     |
# |    total_timesteps | 127528   |
# | train/             |          |
# |    actor_loss      | -78      |
# |    critic_loss     | 0.226    |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | 0.36     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 127427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 814      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 60       |
# |    time_elapsed    | 2190     |
# |    total_timesteps | 131528   |
# | train/             |          |
# |    actor_loss      | -78.3    |
# |    critic_loss     | 0.15     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | 0.0489   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 902      |
# |    ep_rew_mean     | 808      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 60       |
# |    time_elapsed    | 2223     |
# |    total_timesteps | 133572   |
# | train/             |          |
# |    actor_loss      | -78.4    |
# |    critic_loss     | 0.332    |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | 1.43     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 133471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 819      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 60       |
# |    time_elapsed    | 2288     |
# |    total_timesteps | 137572   |
# | train/             |          |
# |    actor_loss      | -78.5    |
# |    critic_loss     | 0.371    |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 137471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 60       |
# |    time_elapsed    | 2353     |
# |    total_timesteps | 141572   |
# | train/             |          |
# |    actor_loss      | -78.5    |
# |    critic_loss     | 0.265    |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | 0.314    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 141471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 823      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 60       |
# |    time_elapsed    | 2403     |
# |    total_timesteps | 144625   |
# | train/             |          |
# |    actor_loss      | -79      |
# |    critic_loss     | 0.511    |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | 0.00649  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 144524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 930      |
# |    ep_rew_mean     | 842      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 60       |
# |    time_elapsed    | 2468     |
# |    total_timesteps | 148625   |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 0.224    |
# |    ent_coef        | 0.0181   |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 148524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 940      |
# |    ep_rew_mean     | 852      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 60       |
# |    time_elapsed    | 2534     |
# |    total_timesteps | 152625   |
# | train/             |          |
# |    actor_loss      | -79.2    |
# |    critic_loss     | 0.119    |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 152524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 940      |
# |    ep_rew_mean     | 854      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 60       |
# |    time_elapsed    | 2599     |
# |    total_timesteps | 156625   |
# | train/             |          |
# |    actor_loss      | -79      |
# |    critic_loss     | 0.47     |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | -0.099   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 156524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 862      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 60       |
# |    time_elapsed    | 2665     |
# |    total_timesteps | 160625   |
# | train/             |          |
# |    actor_loss      | -79.9    |
# |    critic_loss     | 0.191    |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | 0.296    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 160524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 860      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 60       |
# |    time_elapsed    | 2730     |
# |    total_timesteps | 164625   |
# | train/             |          |
# |    actor_loss      | -79.6    |
# |    critic_loss     | 0.229    |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | -0.0397  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 164524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 860      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 60       |
# |    time_elapsed    | 2795     |
# |    total_timesteps | 168625   |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 0.247    |
# |    ent_coef        | 0.0171   |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 168524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 863      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 60       |
# |    time_elapsed    | 2861     |
# |    total_timesteps | 172625   |
# | train/             |          |
# |    actor_loss      | -80.2    |
# |    critic_loss     | 0.221    |
# |    ent_coef        | 0.0165   |
# |    ent_coef_loss   | 0.459    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 172524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 865      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 60       |
# |    time_elapsed    | 2926     |
# |    total_timesteps | 176625   |
# | train/             |          |
# |    actor_loss      | -80.2    |
# |    critic_loss     | 0.145    |
# |    ent_coef        | 0.0162   |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 176524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 870      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 60       |
# |    time_elapsed    | 2991     |
# |    total_timesteps | 180625   |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 0.158    |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | 0.762    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 180524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 952      |
# |    ep_rew_mean     | 878      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 60       |
# |    time_elapsed    | 3057     |
# |    total_timesteps | 184625   |
# | train/             |          |
# |    actor_loss      | -80.8    |
# |    critic_loss     | 0.213    |
# |    ent_coef        | 0.0161   |
# |    ent_coef_loss   | -0.956   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 184524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | 891      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 60       |
# |    time_elapsed    | 3122     |
# |    total_timesteps | 188625   |
# | train/             |          |
# |    actor_loss      | -81.3    |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.0168   |
# |    ent_coef_loss   | -0.742   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 188524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | 893      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 60       |
# |    time_elapsed    | 3188     |
# |    total_timesteps | 192625   |
# | train/             |          |
# |    actor_loss      | -80.9    |
# |    critic_loss     | 0.0852   |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | -0.551   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 192524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | 893      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 60       |
# |    time_elapsed    | 3253     |
# |    total_timesteps | 196625   |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 0.186    |
# |    ent_coef        | 0.016    |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 196524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | 894      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 60       |
# |    time_elapsed    | 3319     |
# |    total_timesteps | 200625   |
# | train/             |          |
# |    actor_loss      | -81.5    |
# |    critic_loss     | 0.199    |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -0.416   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 200524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | 891      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 60       |
# |    time_elapsed    | 3385     |
# |    total_timesteps | 204625   |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 0.185    |
# |    ent_coef        | 0.0168   |
# |    ent_coef_loss   | 0.167    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 204524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 901      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 60       |
# |    time_elapsed    | 3450     |
# |    total_timesteps | 208625   |
# | train/             |          |
# |    actor_loss      | -81.2    |
# |    critic_loss     | 0.458    |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | -0.745   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 208524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 901      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 60       |
# |    time_elapsed    | 3516     |
# |    total_timesteps | 212625   |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 0.2      |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | 0.482    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 212524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 902      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 60       |
# |    time_elapsed    | 3581     |
# |    total_timesteps | 216625   |
# | train/             |          |
# |    actor_loss      | -81.7    |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 0.0163   |
# |    ent_coef_loss   | 0.609    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 216524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 904      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 60       |
# |    time_elapsed    | 3646     |
# |    total_timesteps | 220625   |
# | train/             |          |
# |    actor_loss      | -81.8    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.0161   |
# |    ent_coef_loss   | 0.519    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 220524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 904      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 60       |
# |    time_elapsed    | 3712     |
# |    total_timesteps | 224625   |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 0.143    |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 224524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 971      |
# |    ep_rew_mean     | 905      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 60       |
# |    time_elapsed    | 3777     |
# |    total_timesteps | 228625   |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.0161   |
# |    ent_coef_loss   | -0.899   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 228524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 924      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 60       |
# |    time_elapsed    | 3843     |
# |    total_timesteps | 232625   |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.0157   |
# |    ent_coef_loss   | 0.631    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 232524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 924      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 60       |
# |    time_elapsed    | 3909     |
# |    total_timesteps | 236625   |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 236524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 991      |
# |    ep_rew_mean     | 923      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 60       |
# |    time_elapsed    | 3974     |
# |    total_timesteps | 240625   |
# | train/             |          |
# |    actor_loss      | -82.3    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 933      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 60       |
# |    time_elapsed    | 4040     |
# |    total_timesteps | 244625   |
# | train/             |          |
# |    actor_loss      | -81.6    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.016    |
# |    ent_coef_loss   | 0.511    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 244524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 933      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 60       |
# |    time_elapsed    | 4106     |
# |    total_timesteps | 248625   |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 0.171    |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | 0.768    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 934      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 60       |
# |    time_elapsed    | 4172     |
# |    total_timesteps | 252625   |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 0.558    |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | 0.462    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 252524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 992      |
# |    ep_rew_mean     | 926      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 60       |
# |    time_elapsed    | 4224     |
# |    total_timesteps | 255815   |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -0.599   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255714   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 992      |
# |    ep_rew_mean     | 927      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 60       |
# |    time_elapsed    | 4290     |
# |    total_timesteps | 259815   |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259714   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 921      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 60       |
# |    time_elapsed    | 4340     |
# |    total_timesteps | 262835   |
# | train/             |          |
# |    actor_loss      | -82.3    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 962      |
# |    ep_rew_mean     | 902      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 60       |
# |    time_elapsed    | 4373     |
# |    total_timesteps | 264856   |
# | train/             |          |
# |    actor_loss      | -82.7    |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | 0.943    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264755   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 883      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 60       |
# |    time_elapsed    | 4406     |
# |    total_timesteps | 266878   |
# | train/             |          |
# |    actor_loss      | -82.3    |
# |    critic_loss     | 0.162    |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | 0.114    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 883      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 60       |
# |    time_elapsed    | 4471     |
# |    total_timesteps | 270878   |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 0.247    |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | -0.406   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 884      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 60       |
# |    time_elapsed    | 4537     |
# |    total_timesteps | 274878   |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 0.322    |
# |    ent_coef        | 0.0157   |
# |    ent_coef_loss   | 0.409    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 274777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 885      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 60       |
# |    time_elapsed    | 4602     |
# |    total_timesteps | 278878   |
# | train/             |          |
# |    actor_loss      | -82.6    |
# |    critic_loss     | 0.237    |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | -0.447   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 278777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 885      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 60       |
# |    time_elapsed    | 4668     |
# |    total_timesteps | 282878   |
# | train/             |          |
# |    actor_loss      | -83.2    |
# |    critic_loss     | 0.106    |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -0.627   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 282777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 884      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 60       |
# |    time_elapsed    | 4733     |
# |    total_timesteps | 286878   |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 0.199    |
# |    ent_coef        | 0.0152   |
# |    ent_coef_loss   | -0.158   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 286777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 943      |
# |    ep_rew_mean     | 884      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 60       |
# |    time_elapsed    | 4798     |
# |    total_timesteps | 290878   |
# | train/             |          |
# |    actor_loss      | -83      |
# |    critic_loss     | 0.103    |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | 0.0495   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 290777   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 933      |
# |    ep_rew_mean     | 875      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 60       |
# |    time_elapsed    | 4847     |
# |    total_timesteps | 293889   |
# | train/             |          |
# |    actor_loss      | -82.6    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.0157   |
# |    ent_coef_loss   | -0.937   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 293788   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 933      |
# |    ep_rew_mean     | 878      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 60       |
# |    time_elapsed    | 4913     |
# |    total_timesteps | 297889   |
# | train/             |          |
# |    actor_loss      | -82.5    |
# |    critic_loss     | 0.175    |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | 0.183    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297788   |
# ---------------------------------
# ...
# |    fps             | 59       |
# |    time_elapsed    | 15023    |
# |    total_timesteps | 893404   |
# | train/             |          |
# |    actor_loss      | -95.8    |
# |    critic_loss     | 4.84     |
# |    ent_coef        | 0.0211   |
# |    ent_coef_loss   | -0.139   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 893303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 960      |
# |    ep_rew_mean     | 2.24e+03 |
# | time/              |          |
# |    episodes        | 1004     |
# |    fps             | 59       |
# |    time_elapsed    | 15091    |
# |    total_timesteps | 897404   |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 1.7      |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -0.859   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 897303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 960      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 1008     |
# |    fps             | 59       |
# |    time_elapsed    | 15159    |
# |    total_timesteps | 901404   |
# | train/             |          |
# |    actor_loss      | -98.8    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -0.446   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 901303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 1012     |
# |    fps             | 59       |
# |    time_elapsed    | 15227    |
# |    total_timesteps | 905404   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 3.1      |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | -0.353   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 905303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | 2.45e+03 |
# | time/              |          |
# |    episodes        | 1016     |
# |    fps             | 59       |
# |    time_elapsed    | 15295    |
# |    total_timesteps | 909404   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 0.498    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 909303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | 2.51e+03 |
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 59       |
# |    time_elapsed    | 15363    |
# |    total_timesteps | 913404   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | 0.746    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 913303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 986      |
# |    ep_rew_mean     | 2.58e+03 |
# | time/              |          |
# |    episodes        | 1024     |
# |    fps             | 59       |
# |    time_elapsed    | 15431    |
# |    total_timesteps | 917404   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 1.78     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -1.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 917303   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.56e+03 |
# | time/              |          |
# |    episodes        | 1028     |
# |    fps             | 59       |
# |    time_elapsed    | 15484    |
# |    total_timesteps | 920467   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 4.75     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 920366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.62e+03 |
# | time/              |          |
# |    episodes        | 1032     |
# |    fps             | 59       |
# |    time_elapsed    | 15552    |
# |    total_timesteps | 924467   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.022    |
# |    ent_coef_loss   | -0.551   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 924366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.68e+03 |
# | time/              |          |
# |    episodes        | 1036     |
# |    fps             | 59       |
# |    time_elapsed    | 15620    |
# |    total_timesteps | 928467   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 2.03     |
# |    ent_coef        | 0.0222   |
# |    ent_coef_loss   | -0.757   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 928366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 1040     |
# |    fps             | 59       |
# |    time_elapsed    | 15689    |
# |    total_timesteps | 932467   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 2.85     |
# |    ent_coef        | 0.0226   |
# |    ent_coef_loss   | 0.332    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 932366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 1044     |
# |    fps             | 59       |
# |    time_elapsed    | 15757    |
# |    total_timesteps | 936467   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0228   |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 936366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.76e+03 |
# | time/              |          |
# |    episodes        | 1048     |
# |    fps             | 59       |
# |    time_elapsed    | 15825    |
# |    total_timesteps | 940467   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 3.93     |
# |    ent_coef        | 0.0225   |
# |    ent_coef_loss   | -0.443   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 940366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.78e+03 |
# | time/              |          |
# |    episodes        | 1052     |
# |    fps             | 59       |
# |    time_elapsed    | 15894    |
# |    total_timesteps | 944467   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 3.16     |
# |    ent_coef        | 0.024    |
# |    ent_coef_loss   | 0.927    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 944366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.81e+03 |
# | time/              |          |
# |    episodes        | 1056     |
# |    fps             | 59       |
# |    time_elapsed    | 15962    |
# |    total_timesteps | 948467   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0225   |
# |    ent_coef_loss   | 0.735    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 948366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.86e+03 |
# | time/              |          |
# |    episodes        | 1060     |
# |    fps             | 59       |
# |    time_elapsed    | 16030    |
# |    total_timesteps | 952467   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0231   |
# |    ent_coef_loss   | -1.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 952366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | 2.89e+03 |
# | time/              |          |
# |    episodes        | 1064     |
# |    fps             | 59       |
# |    time_elapsed    | 16098    |
# |    total_timesteps | 956467   |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 2.06     |
# |    ent_coef        | 0.0219   |
# |    ent_coef_loss   | 0.775    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 956366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 2.95e+03 |
# | time/              |          |
# |    episodes        | 1068     |
# |    fps             | 59       |
# |    time_elapsed    | 16152    |
# |    total_timesteps | 959636   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 6.13     |
# |    ent_coef        | 0.023    |
# |    ent_coef_loss   | -0.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 959535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 2.99e+03 |
# | time/              |          |
# |    episodes        | 1072     |
# |    fps             | 59       |
# |    time_elapsed    | 16220    |
# |    total_timesteps | 963636   |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 7.16     |
# |    ent_coef        | 0.0227   |
# |    ent_coef_loss   | 0.853    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 963535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.01e+03 |
# | time/              |          |
# |    episodes        | 1076     |
# |    fps             | 59       |
# |    time_elapsed    | 16289    |
# |    total_timesteps | 967636   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 2.96     |
# |    ent_coef        | 0.0222   |
# |    ent_coef_loss   | 0.688    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 967535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.04e+03 |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 59       |
# |    time_elapsed    | 16357    |
# |    total_timesteps | 971636   |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 3.81     |
# |    ent_coef        | 0.0234   |
# |    ent_coef_loss   | 0.469    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 971535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.08e+03 |
# | time/              |          |
# |    episodes        | 1084     |
# |    fps             | 59       |
# |    time_elapsed    | 16425    |
# |    total_timesteps | 975636   |
# | train/             |          |
# |    actor_loss      | -124     |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.023    |
# |    ent_coef_loss   | 0.176    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 975535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.1e+03  |
# | time/              |          |
# |    episodes        | 1088     |
# |    fps             | 59       |
# |    time_elapsed    | 16493    |
# |    total_timesteps | 979636   |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 3.52     |
# |    ent_coef        | 0.0242   |
# |    ent_coef_loss   | 1.65     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 979535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.13e+03 |
# | time/              |          |
# |    episodes        | 1092     |
# |    fps             | 59       |
# |    time_elapsed    | 16561    |
# |    total_timesteps | 983636   |
# | train/             |          |
# |    actor_loss      | -124     |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0231   |
# |    ent_coef_loss   | -0.218   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 983535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.15e+03 |
# | time/              |          |
# |    episodes        | 1096     |
# |    fps             | 59       |
# |    time_elapsed    | 16629    |
# |    total_timesteps | 987636   |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 5.08     |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | 0.294    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 987535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.17e+03 |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 59       |
# |    time_elapsed    | 16698    |
# |    total_timesteps | 991636   |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 3.79     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | 1.94     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 991535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.23e+03 |
# | time/              |          |
# |    episodes        | 1104     |
# |    fps             | 59       |
# |    time_elapsed    | 16766    |
# |    total_timesteps | 995636   |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -0.552   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | 3.27e+03 |
# | time/              |          |
# |    episodes        | 1108     |
# |    fps             | 59       |
# |    time_elapsed    | 16834    |
# |    total_timesteps | 999636   |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | 0.751    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999535   |
# ---------------------------------

# %%
obs, info = env.reset()
for _ in range(1000):
    action, _states = model.predict(obs, deterministic=True) 
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()

# %%
# Saving the model
model.save("sac_ant_3legs")

# Loading the model
# model = SAC.load("sac_ant")

# %%
import os
import random
import time
from dataclasses import dataclass
from datetime import datetime
from pathlib import Path

import gymnasium as gym
import numpy as np
import torch
import torch.nn.functional as F  # noqa: N812
from stable_baselines3.common.buffers import ReplayBuffer
from torch import nn, optim
from torch.utils.tensorboard import SummaryWriter  # type: ignore
from transformers import DistilBertConfig, DistilBertModel

# %%
from scripts.last_hope import Actor
