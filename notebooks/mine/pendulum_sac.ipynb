# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from libs.my_sac.ac import ActorCritic

# %%
env = gym.make("Pendulum-v1", render_mode="human")

# %%
ac = ActorCritic(env)

# %%
ac.train(300)
# Out:
# ...
#   1%|          | 2/300 [00:24<1:00:05, 12.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ac.train(300)
#
# File c:\Users\COCUTERSASHA\Desktop\ohMy\new_life\libs\my_sac\ac.py:246, in ActorCritic.train(self, num_epochs)
#     241     a0 = a0.flatten().numpy()
#     242     # big_mask = np.greater(action_max, a0)
#     243     # small_mask = np.less(a0, action_max)
#     244     # a0[big_mask] = action_max[big_mask]
#     245     # a0[small_mask] = action_max[small_mask]
# --> 246     s1, r1, terminated, truncated, inform = self.env.step(a0)
#     247     rewardy += r1
#     248 self.reward.append(rewardy)
#
# File c:\Users\COCUTERSASHA\.micromamba\envs\ml311\Lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
# ...

# %%
plt.plot(ac.reward)
plt.show()

# %%
# env.render()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
